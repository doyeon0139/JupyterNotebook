# %%
from flask import Flask, render_template, request

import selenium
from bs4 import BeautifulSoup
from selenium import webdriver

import time
import requests

app = Flask(__name__)



@app.route('/')
def hello_world():
    return render_template("index_2.html")


@app.route('/result', methods=['POST'])
def result() :

    if request.method == 'POST' :

        keyword = request.form['input1']
        page = request.form['input2']

        daum_list = []

        driver = webdriver.Chrome()
        
        url = 'https://www.daum.net/'

        time.sleep(1)
        driver.get(url)
        time.sleep(3)

        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')

        for i in range(1, int(page)+1) :
            url = 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q=' + keyword + '&p=' + page
            time.sleep(1)
            driver.get(url)
            time.sleep(3)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')

            for i in soup.find_all("a") :
                print(i.text)
                daum_list.append(i.text)

        return render_template('result_1.html', daum_list = daum_list)



if __name__ == '__main__':
    app.run(host='127.0.0.1', port='8080')
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8080/ (Press CTRL+C to quit)
# 127.0.0.1 - - [19/May/2022 17:43:12] "GET / HTTP/1.1" 200 -
# 본문 바로가기
# 메뉴 바로가기
# 실시간이슈 바로가기
#
#
#
# 서제스트란?
# 로그인
# 메일받은메일수
# Daum아이디 만들기
# Daum 미니 사이트맵
# 카페
# 뉴스
# 지도
# 쇼핑
# 블로그
# 티스토리
# 브런치
# 카카오TV
# 게임
# 스포츠
# 연예
# 영화
# 웹툰
# 멜론
# 어학사전
# 번역
# 단어장
# 맞춤법검사
# 백과사전
# 금융
# 부동산
# 자동차
# 메이커스
# 같이가치
# 전체보기
# 통합검색
#
# 이미지
#
#
# 동영상
#
#
# 뉴스
#
#
# 통합웹
#
#
# 블로그
#
#
# 카페
#
#
# 웹문서
#
#
# 더보기/접기
#
#
# 사이트
#
#
#
# 어학사전
# 새창
#
#
#
#
# 지도
# 새창
#
#
#
#
# 백과사전
# 새창
#
#
#
#
# 쇼핑
# 새창
#
#
#
# 책
#
#
# 멜론뮤직
#
#
# 브런치
#
#
# 카카오스토리
#
# 서비스 안내
# 다음뉴스 고객센터
# 정확도순
# 최신순
# 오래된순
# 관련뉴스 닫기
#  기간옵션더보기
#  전체
#  최근 1일
#  최근 1주
#  최근 1개월
#  최근 6개월
#  최근 1년
#
#
#  언론사옵션더보기
# ㄱ
# ㄴ
# ㄷ
# ㄹ
# ㅁ
# ㅂ
# ㅅ
# ㅇ
# ㅈ
# ㅊ
# ㅋ
# ㅌ
# ㅍ
# ㅎ
# ...

# %%
from flask import Flask, render_template, request

import selenium
from bs4 import BeautifulSoup
from selenium import webdriver

import time
import requests

app = Flask(__name__)



@app.route('/')
def hello_world():
    return render_template("index_2.html")


@app.route('/result', methods=['POST'])
def result() :

    if request.method == 'POST' :

        keyword = request.form['input1']
        page = request.form['input2']

        daum_list = []

        driver = webdriver.Chrome()

        for i in range(1, int(page)+1) :
            url = 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q={}&p={}'.format(keyword, i)
            driver.get(url)
            time.sleep(2)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
           
            for i in soup.select('#newsColl > div.cont_divider > ul > li > div.wrap_cont > a') :
                daum_list.append(i.text)

        return render_template('result_1.html', daum_list = daum_list)



if __name__ == '__main__':
    app.run(host='127.0.0.1', port='8080')
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8080/ (Press CTRL+C to quit)
# 127.0.0.1 - - [19/May/2022 17:41:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2022 17:41:38] "POST /result HTTP/1.1" 200 -

# %% [markdown]
# # 네이버

# %%
from flask import Flask, render_template, request

import selenium
from bs4 import BeautifulSoup
from selenium import webdriver

import time
import requests

app = Flask(__name__)



@app.route('/')
def hello_world():
    return render_template("index_2.html")


@app.route('/result', methods=['POST'])
def result() :

    if request.method == 'POST' :

        keyword = request.form['input1']
        page = request.form['input2']

        daum_list = []

        driver = webdriver.Chrome()
        
        url = 'https://www.naver.com/'

        time.sleep(1)
        driver.get(url)
        time.sleep(3)

        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')

        for i in range(1, int(page)+1) :
            url = f'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%{keyword}&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=58&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all&start={page}1'
            time.sleep(1)
            driver.get(url)
            time.sleep(3)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')

            for i in soup.find_all("a", class_='news_tit') :
                print(i.text)
                daum_list.append(i.text)
                

        return render_template('result_1.html', daum_list = daum_list)



if __name__ == '__main__':
    app.run(host='127.0.0.1', port='8080')
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8080/ (Press CTRL+C to quit)
# 127.0.0.1 - - [19/May/2022 17:47:10] "GET / HTTP/1.1" 200 -
# "오염수 방출, 윤석열 반대 안 해"…日언론 '주목'
# ‘윤석열 사단’ 檢 요직 싹쓸이
# 한동훈 첫 검찰 인사…'윤석열 사단' 대거 복귀
# ‘인천공항 민영화’···MB 이어 윤석열 정부서도 재연
# 윤석열 대통령 취임 후 첫 5·18 참배, 조아라 여사는?
# 민주당 인천서 출정식 "윤석열 정부에 경고장‥민생 일꾼 선택해달라"
# 윤석열 대통령 5·18 기념식 입장
# 윤석열 대통령, 민주의문으로 입장…보수대통령 최초(종합)
# 오늘 5·18 42주년 기념식…윤석열 대통령 참석
# "내가 하면 윤석열 정부도 한다"…현장·윤심·현안 강조한 김은혜
# 127.0.0.1 - - [19/May/2022 17:47:34] "POST /result HTTP/1.1" 200 -

# %%
'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%9C%A4%EC%84%9D%EC%97%B4&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=26&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all&start=11'

# %%
'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%9C%A4%EC%84%9D%EC%97%B4&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=47&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all&start=21'

# %%
'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%9C%A4%EC%84%9D%EC%97%B4&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=58&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all&start=1'
