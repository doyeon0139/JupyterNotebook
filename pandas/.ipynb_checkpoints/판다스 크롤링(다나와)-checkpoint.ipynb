# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
import warnings
import folium

warnings.filterwarnings(action = 'ignore')
mpl.rcParams['axes.unicode_minus'] = False

path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

# %%
# 다나와 사이트에서 원하는 조건의 상품 조회

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
query = '무선청소기'
url = f'http://search.danawa.com/dsearch.php?query={query}&tab=main'
driver.get(url)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
title_lst = []
price_lst = []
spec_lst = []

for lst in soup.select('#productListArea > div.main_prodlist.main_prodlist_list > ul > li.prod_item'):
    if lst.select('div.prod_main_info') and lst['class'] == ['prod_item']:
        title = lst.select('p.prod_name > a')[0].text
        price = lst.select('p.price_sect > a')[0].text
        spec = lst.select('div.spec_list')[0].text
        print(title)
        print(price)
        print(spec)
        title_lst.append(title)
        price_lst.append(price)
        spec_lst.append(spec)
        print('-'*60)
# Out:
# 삼성전자 비스포크 제트 VS20A956A3
# 560,310원
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 흡입력: 210W / 제트싸이클론 / 디지털인버터모터 / [배터리] 충전시간: 3시간30분 / 사용시간(개당): 1시간 / 분리형 (1개) / 리튬이온 / [필터] 5단계여과 / [기능] 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / 자동먼지비움 / [구성] 바닥 / 솔형 / 틈새 / 연장툴 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 색상: 미스티화이트 / 무게: 2.5kg / 액세서리크래들  / 크기(가로x세로x깊이): 250x930x202mm
# ------------------------------------------------------------
# LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9571
# 1,056,700원
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / 소비전력: 590W / [성능] 흡입력: 210W / 2중터보싸이클론 / 스마트인버터모터 / [배터리] 충전시간: 4시간 / 사용시간(개당): 1시간 / 분리형 (2개) / 리튬이온 / [필터] 분리형배기필터 / 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / 자동먼지비움 / [구성] 바닥 / 물걸레 / 침구 / 솔형 / 틈새 / 올인원타워 / [부가] 색상: 카밍베이지 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm
# ------------------------------------------------------------
# 샤오미 CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)
# 61,850원
# ...

# %%
df = pd.DataFrame({'title':title_lst,'price':price_lst,'spec':spec_lst})

# %%
df
# Out:
#                                     title       price  \
# 0                 삼성전자 비스포크 제트 VS20A956A3    560,310원
# 1       LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9571  1,056,700원
# 2   샤오미 CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)     61,850원
# 3                 베이스어스 차량용 청소기 A3 (해외구매)     49,260원
# 4                 삼성전자 비스포크 제트 VS20A957E3    838,500원
# 5                    샤오미 TROUVER POWER 11     79,050원
# 6               LG전자 코드제로 ThinQ A9S A9370    630,600원
# 7           LG전자 코드제로 ThinQ A9S AS9370IKT    807,030원
# 8                         다이슨 V10 플러피 오리진    554,690원
# 9            샤오미 미지아 차량용 핸디 무선 청소기 (해외구매)     41,020원
# 10                            샤오미 드리미 V10    154,445원
# 11               일렉트로룩스 WELL Q6 WQ61-1OGG    131,510원
# 12     샤오미 CLEANFLY 차량용 무선 청소기 3세대 (해외구매)     58,540원
# 13                            샤오미 드리미 V11    208,320원
# 14             LG전자 코드제로 ThinQ A9S AS9470    921,200원
# 15                        델로라 V11 파워 300W    104,900원
# ...
