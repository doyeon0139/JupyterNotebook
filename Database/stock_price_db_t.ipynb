# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests
from bs4 import BeautifulSoup

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
url = 'https://finance.naver.com/item/sise_day.naver?code=005930&page=11'

# %%
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

# %%
pd.read_html(res.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2232/3268708569.py in <module>
# ----> 1 pd.read_html(res.text)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1096     io = stringify_path(io)
#    1097
# -> 1098     return _parse(
#    1099         flavor=flavor,
#    1100         io=io,
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     924     else:
#     925         assert retained is not None  # for mypy
# --> 926         raise retained
#     927
#     928     ret = []
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     904
#     905         try:
# --> 906             tables = p.parse_tables()
#     907         except ValueError as caught:
#     908             # if `io` is an io-like object, check if it's seekable
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in parse_tables(self)
#     220         list of parsed (header, body, footer) tuples from tables.
#     221         """
# --> 222         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     223         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     224
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in _parse_tables(self, doc, match, attrs)
#     550
#     551         if not tables:
# --> 552             raise ValueError("No tables found")
#     553
#     554         result = []
#
# ValueError: No tables found

# %%
driver = webdriver.Chrome()
driver.get(url)
time.sleep(0.5)
html = driver.page_source

df = pd.read_html(html)[0]
df.dropna(inplace=True)
df

driver.close()
# Out:
#             날짜       종가     전일비       시가       고가       저가         거래량
# 1   2021.09.09  75300.0  1000.0  76400.0  76600.0  75000.0  17600770.0
# 2   2021.09.08  76300.0   200.0  76000.0  76400.0  75600.0  11798147.0
# 3   2021.09.07  76100.0  1200.0  77100.0  77100.0  75900.0  13239401.0
# 4   2021.09.06  77300.0   700.0  76800.0  77600.0  76600.0  12861180.0
# 5   2021.09.03  76600.0   600.0  76400.0  76700.0  76000.0  12096419.0
# 9   2021.09.02  76000.0   800.0  76800.0  76800.0  75700.0  15347486.0
# 10  2021.09.01  76800.0   100.0  76700.0  77100.0  75900.0  16114775.0
# 11  2021.08.31  76700.0  2100.0  74900.0  76700.0  74300.0  24630370.0
# 12  2021.08.30  74600.0   300.0  75400.0  75500.0  74200.0  12686999.0
# 13  2021.08.27  74300.0   300.0  74300.0  75000.0  73800.0  15172748.0

# %%
df = pd.read_csv('./data/universe_code.csv')
codes = df.종목코드.apply(lambda x: x[1:]).values
codes
# Out:
# array(['000210', '000220', '000240', '000250', '000660', '000990',
#        '001340', '001390', '001500', '001750', '001800', '001820',
#        '001880', '002310', '002350', '002390', '002870', '003090',
#        '003220', '003410', '003530', '003550', '003670', '003780',
#        '003850', '004000', '004170', '004490', '004590', '005290',
#        '005670', '005690', '005880', '005930', '006060', '006220',
#        '006390', '006400', '006620', '006650', '006740', '007330',
#        '007340', '007570', '007700', '008490', '009150', '009420',
#        '009780', '009970', '010050', '010130', '010240', '010640',
#        '010780', '011040', '011170', '011330', '011780', '012330',
#        '012510', '012630', '012700', '012750', '012790', '013030',
#        '013120', '013810', '013890', '014570', '014680', '014830',
#        '015230', '015710', '016090', '016360', '016580', '016600',
#        '016610', '017040', '017510', '017890', '017960', '018250',
#        '018260', '018310', '019550', '020000', '020150', '020710',
#        '021080', '021240', '022220', '023590', '023600', '023760',
#        '023770', '023900', '023910', '024110', '024120', '024720',
#        '025900', '026890', '026960', '027360', '027410', '027970',
#        '028100', '028670', '029460', '029780', '029960', '030190',
#        '030210', '030520', '030530', '030610', '031390', '031430',
#        '032080', '032190', '032500', '032560', '032620', '032850',
#        '033100', '033130', '033160', '033270', '033290', '033500',
#        '033640', '033660', '033780', '033830', '034810', '034830',
#        '035250', '035420', '035460', '035600', '035900', '036120',
#        '270520', '270870', '271560', '272110', '272290', '272550',
#        '277410', '278280', '278650', '281740', '281820', '282690',
#        '284740', '285490', '290120', '290270', '290380', '290520',
#        '290650', '290670', '290720', '293480', '297090', '299900',
#        '300120', '302430', '306040', '308100', '312610', '317330',
#        '322180', '327260', '900250', '900270', '900280', '900300',
#        '900310', '900340', '950110', '950180'], dtype=object)

# %%
import MySQLdb

db = MySQLdb.connect(host='localhost', port=3306, user='root', passwd = '1234')
cursor = db.cursor()

# %%
sql = 'show databases;'
pd.read_sql(sql, db)
# Out:
#               Database
# 0   information_schema
# 1            budongsan
# 2            employees
# 3           finance_db
# 4            gmarketdb
# 5                mysql
# 6   performance_schema
# 7               sakila
# 8               shopdb
# 9                sqldb
# 10                 sys
# 11             tabledb
# 12               world

# %%
sql = 'use finance_db;'
cursor.execute(sql)
# Out:
# 0

# %%
sql = """
create table if not exists stock_table(
code char(6),
date date,
close float,
margin float,
start float,
high float,
low float,
volume float
)
"""

cursor.execute(sql)
# Out:
# 0

# %%
url = 'https://finance.naver.com/item/sise_day.naver?code={}&page={}'.format(code, num)
# Out:
# 'https://finance.naver.com/item/sise_day.naver?code=005930&page=11'

# %%
url = 'https://finance.naver.com/item/sise_day.naver?code={}&page={}'
driver = webdriver.Chrome()

for code in codes[:10]:
    print(code, '==========')
    
    for i in range(1,5):
        driver.get(url.format(code, i))
        time.sleep(0.5)
        html = driver.page_source
        
        df = pd.read_html(html)[0]
        df.dropna(inplace=True)
#         print(df)
        print('---------')
    
        for i in range(len(df)):
            code = code
            date = df.iloc[i][0]
            close = df.iloc[i][1]            
            margin = df.iloc[i][2]
            start = df.iloc[i][3]
            high = df.iloc[i][4]
            low = df.iloc[i][5]
            volume = df.iloc[i][6]
            
            sql = """
            insert into stock_table values('{}','{}','{}','{}','{}','{}','{}','{}');
            """.format(code, date, close, margin, start, high, low, volume)
        
            cursor.execute(sql)
            
driver.close()
# Out:
# 000210 ==========
# ---------
# ---------
# ---------
# ---------
# 000220 ==========
# ---------
# ---------
# ---------
# ---------
# 000240 ==========
# ---------
# ---------
# ---------
# ---------
# 000250 ==========
# ---------
# ---------
# ---------
# ---------
# 000660 ==========
# ---------
# ---------
# ---------
# ---------
# 000990 ==========
# ---------
# ---------
# ---------
# ---------
# 001340 ==========
# ---------
# ---------
# ---------
# ---------
# 001390 ==========
# ---------
# ---------
# ---------
# ---------
# 001500 ==========
# ---------
# ---------
# ---------
# ---------
# 001750 ==========
# ---------
# ---------
# ---------
# ---------

# %%
sql = 'select * from stock_table;'

st_price = pd.read_sql(sql, db)
st_price
# Out:
#        code        date    close  margin    start     high      low   volume
# 0    000210  2022-02-09  60200.0   600.0  59700.0  60400.0  59000.0  11770.0
# 1    000210  2022-02-08  59600.0  1000.0  59100.0  61000.0  58600.0  83130.0
# 2    000210  2022-02-07  58600.0  1100.0  57500.0  58800.0  57000.0  53386.0
# 3    000210  2022-02-04  57500.0   900.0  56900.0  57800.0  56600.0  34228.0
# 4    000210  2022-02-03  56600.0   700.0  56300.0  57500.0  56300.0  44961.0
# ..      ...         ...      ...     ...      ...      ...      ...      ...
# 395  001750  2021-12-16  16000.0    50.0  16050.0  16100.0  15950.0  30691.0
# 396  001750  2021-12-15  16050.0    50.0  16000.0  16150.0  15900.0  48967.0
# 397  001750  2021-12-14  16100.0   100.0  15850.0  16100.0  15800.0  37002.0
# 398  001750  2021-12-13  16000.0   250.0  15700.0  16050.0  15700.0  36308.0
# 399  001750  2021-12-10  15750.0   150.0  15850.0  15900.0  15700.0  26953.0
#
# [400 rows x 8 columns]

# %%
st_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   code    400 non-null    object
#  1   date    400 non-null    object
#  2   close   400 non-null    float64
#  3   margin  400 non-null    float64
#  4   start   400 non-null    float64
#  5   high    400 non-null    float64
#  6   low     400 non-null    float64
#  7   volume  400 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 25.1+ KB

# %%
st_price.date.iloc[0]
# Out:
# datetime.date(2022, 2, 9)

# %%
import datetime

# %%
st_price[st_price.date == datetime.date(2022, 2, 9)]
# Out:
#        code        date     close  margin     start      high       low  \
# 0    000210  2022-02-09   60200.0   600.0   59700.0   60400.0   59000.0
# 40   000220  2022-02-09    8640.0  1460.0    7220.0    8880.0    7200.0
# 80   000240  2022-02-09   13650.0   200.0   13650.0   13700.0   13500.0
# 120  000250  2022-02-09   36100.0   300.0   36500.0   36650.0   35550.0
# 160  000660  2022-02-09  127000.0  2000.0  127000.0  128000.0  126500.0
# 200  000990  2022-02-09   70700.0   600.0   71300.0   71800.0   70600.0
# 240  001340  2022-02-09    4565.0    90.0    4510.0    4590.0    4500.0
# 280  001390  2022-02-09   27100.0   250.0   27000.0   27300.0   26950.0
# 320  001500  2022-02-09   11450.0   100.0   11400.0   11500.0   11350.0
# 360  001750  2022-02-09   15600.0   400.0   15200.0   15700.0   15150.0
#
#         volume
# 0      11770.0
# 40   8560600.0
# 80     16558.0
# 120    28121.0
# 160  1867600.0
# 200   301735.0
# 240   112719.0
# 280    15479.0
# 320    17895.0
# 360    13826.0

# %%
sql = 'select * from stock_table where code=000220;'

st_price = pd.read_sql(sql, db)
st_price
# Out:
#       code        date   close  margin   start    high     low     volume
# 0   000220  2022-02-09  8640.0  1460.0  7220.0  8880.0  7200.0  8560600.0
# 1   000220  2022-02-08  7180.0   100.0  7250.0  7310.0  7110.0   103370.0
# 2   000220  2022-02-07  7280.0    80.0  7250.0  7340.0  7110.0   141024.0
# 3   000220  2022-02-04  7200.0    20.0  7120.0  7290.0  7080.0   160387.0
# 4   000220  2022-02-03  7180.0   360.0  6970.0  7600.0  6930.0   566487.0
# 5   000220  2022-01-28  6820.0   400.0  6420.0  6900.0  6420.0   374772.0
