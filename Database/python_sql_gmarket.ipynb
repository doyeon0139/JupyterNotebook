# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'http://corners.gmarket.co.kr/Bestsellers'

# %%
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

# %%
# main cate lis

path = '#categoryTabG > li > a'
lis = soup.select(path)

main_url = 'http://corners.gmarket.co.kr'

for li in lis:
    print(main_url + li['href'], li.text)
    
#     main_cate_url = main_url + li['href']
#     main_cate_title = li.text
    
#     res1 = requests.get(main_cate_url)
#     soup1 = BeautifulSoup(res1.text, 'html.parser')
    
#     sub_path = '#subTabG01 > div > ul > li'
# Out:
# http://corners.gmarket.co.kr/Bestsellers ALL
# http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01 패션의류
# http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G02 신발/잡화
# http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G03 화장품/헤어
# http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G04 유아동/출산
# http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G07 식품
# http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G08 생활/주방/건강
# http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G09 가구/침구
# http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G05 스포츠/자동차
# http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06 컴퓨터/전자
# http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G10 도서/음반
# http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G11 여행
# http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G12 e쿠폰/티켓

# %%
# sub cate lis

res1 = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01')
soup1 = BeautifulSoup(res1.text, 'html.parser')

sub_path = '#subTabG01 > div > ul > li > a'
sub_lis = soup1.select(sub_path)

main_url = 'http://corners.gmarket.co.kr'

for sub_li in sub_lis:
    print(li.text, main_url+sub_li['href'])
    
    sub_cate_title = li.text
    sub_cate_url = main_url+sub_li['href']
    
    print(sub_cate_title, sub_cate_url)
# Out:
# 언더웨어 http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01&subGroupCode=S161
# 언더웨어 http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01&subGroupCode=S161
# 언더웨어 http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01&subGroupCode=S162
# 언더웨어 http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01&subGroupCode=S162
# 언더웨어 http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01&subGroupCode=S163
# 언더웨어 http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01&subGroupCode=S163
# 언더웨어 http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01&subGroupCode=S102
# 언더웨어 http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01&subGroupCode=S102
# 언더웨어 http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01&subGroupCode=S002
# 언더웨어 http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01&subGroupCode=S002
# ...

# %%
# sub cate lis


path = '#categoryTabG > li > a'
lis = soup.select(path)

main_url = 'http://corners.gmarket.co.kr'

for li in lis:
    print(main_url + li['href'], li.text)
    
    res1 = requests.get(main_url + li['href'])
    soup1 = BeautifulSoup(res1.text, 'html.parser')

    sub_path = 'li > a'
    sub_lis = soup1.select(sub_path)

    for sub_li in sub_lis:
        print(li.text, main_url+sub_li['href'])

        sub_cate_title = li.text
        sub_cate_url = main_url+sub_li['href']

        print(sub_cate_title, sub_cate_url)
# Out:
# http://corners.gmarket.co.kr/Bestsellers ALL
# ALL http://corners.gmarket.co.kr#skip-navigation-search
# ALL http://corners.gmarket.co.kr#skip-navigation-search
# ALL http://corners.gmarket.co.kr#skip-navigation-category-all
# ALL http://corners.gmarket.co.kr#skip-navigation-category-all
# ALL http://corners.gmarket.co.kr#wrap
# ALL http://corners.gmarket.co.kr#wrap
# ALL http://corners.gmarket.co.kr/BestSellers
# ALL http://corners.gmarket.co.kr/BestSellers
# ALL http://corners.gmarket.co.kr/BestSellers?viewType=C
# ALL http://corners.gmarket.co.kr/BestSellers?viewType=C
# ALL http://corners.gmarket.co.kr/Bestsellers
# ALL http://corners.gmarket.co.kr/Bestsellers
# ALL http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01
# ALL http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01
# ALL http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G02
# ALL http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G02
# ...

# %%
# prod lis

sub_url = 'http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01&subGroupCode=S161'

prod_path = '#gBestWrap > div > div:nth-child(5) > div:nth-child(3) > ul > li'

res3 = requests.get(sub_url)
soup3 = BeautifulSoup(res3.text, 'html.parser')
lis = soup3.select(prod_path)
len(lis)
# Out:
# 100

# %%
# prod details

rank = lis[1].select('li > p')[0].text
prod_title = lis[1].select('li > a')[0].text
prod_url = lis[1].select('li > a')[0]['href']
old_price = lis[1].select('div.item_price div.o-price')[0].text
s_price = lis[1].select('div.item_price strong')[0].text
s_per = lis[1].select('div.item_price em')[0].text

print(rank, prod_title, prod_url, old_price, s_price, s_per)
# Out:
# 2 [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1 http://item.gmarket.co.kr/Item?goodscode=2344225657&ver=637799148815009244 24,900원 24,410원 1%

# %%
url = 'http://corners.gmarket.co.kr/Bestsellers'

res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

path = '#categoryTabG > li > a'
tags = soup.select(path)

main_url = 'http://corners.gmarket.co.kr'

for tag in tags[1]:
#     print(main_url + li['href'], li.text)
    
    main_cate_url = main_url + tag['href']
    main_cate_title = tag.text
    
    print('='*30)
    print()
    print('========= main cate :', main_cate_title, '============')
    
    res1 = requests.get(main_cate_url)
    soup1 = BeautifulSoup(res1.text, 'html.parser')
    
    sub_path = '#subTabG01 > div > ul > li > a'
    sub_path = 'li > a'
    
    sub_lis = soup1.select(sub_path)

    main_url = 'http://corners.gmarket.co.kr'

    for sub_li in sub_lis:
#         print(li.text, main_url+sub_li['href'])

        sub_cate_title = sub_li.text
        sub_cate_url = main_url+sub_li['href']
        
        print('='*30)
        print()
        print('sub cate :', sub_cate_title)

#         print(sub_cate_title, sub_cate_url)

        res3 = requests.get(sub_cate_url)
        soup3 = BeautifulSoup(res3.text, 'html.parser')
        
        prod_path = '#gBestWrap > div > div:nth-child(5) > div:nth-child(3) > ul > li'
        prod_lis = soup3.select(prod_path)
        
        for prod_li in prod_lis:
            try:
                rank = prod_li.select('li > p')[0].text
                prod_title = prod_li.select('li > a')[0].text
                prod_url = prod_li.select('li > a')[0]['href']
                old_price = prod_li.select('div.item_price div.o-price')[0].text
                s_price = prod_li.select('div.item_price strong')[0].text
                s_per = prod_li.select('div.item_price em')[0].text
            except:
                pass

            print(main_cate_title, sub_cate_title, rank, prod_title, prod_url, old_price, s_price, s_per)
            print('----------')
            print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10088/2733779099.py in <module>
#      12 #     print(main_url + li['href'], li.text)
#      13
# ---> 14     main_cate_url = main_url + tag['href']
#      15     main_cate_title = tag.text
#      16
#
# TypeError: string indices must be integers

# %%
res = requests.get('http://corners.gmarket.co.kr/Bestsellers')
soup = BeautifulSoup(res.content, 'html.parser')

data_dict = dict()

categories = soup.select('div.gbest-cate ul.by-group li a')

category_name_list = []
sub_category_name_list = []
ranking_list = []
title_list = []
old_price_list = []
dis_price_list = []
discount_percent_list = []
item_code_list = []
provider_list = []

base_url = 'http://corners.gmarket.co.kr'



for category in categories:
    cate_url = 'http://corners.gmarket.co.kr/' + category['href']
    cate_title = category.text
    
    print('='*30)
    print()
    print(cate_title)
    
    res1 = requests.get(cate_url)
    soup1 = BeautifulSoup(res1.content, 'html.parser')
    
    atags = soup1.select('div.navi.group > ul > li > a')
    
    for a in atags:
#         print(a.text)
#         print(base_url + a['href'])
        sub_url = base_url + a['href']
        sub_title = a.text
        
        print()
        print(sub_title)
        
        res = requests.get(sub_url)
        soup = BeautifulSoup(res.content, 'html.parser')

        prods = soup.select('div.best-list > ul > li')

        for i in range(5,11):     # 5 ~105
#             ranking = prods[i].select('li > p')[0].text
#             title = prods[i].select('li > a.itemname')[0].text
#             prod_url = prods[i].select('li > a.itemname')[0]['href']
#             old_price = prods[i].select('li > div.item_price > div.o-price')[0].text.replace(',','')[:-1]
#             dis_price = prods[i].select('li > div.item_price > div.s-price')[0].text.split('\n')[1].replace(',','')[:-1]
#             dis_per = prods[i].select('li > div.item_price > div.s-price')[0].text.split('\n')[2][:-1]

#             res = requests.get(prod_url)
#             soup = BeautifulSoup(res.content, 'html.parser')

#             provider = soup.select('div.item-topinfo > div > p > a > strong')[0].text
#             prod_code = soup.select('div.item-topinfo > div > p > span.rt > span.pdnum')[0].text.split(':')[1].strip()
#             prod_code
            
            try:
                ranking = prods[i].select('li > p')[0].text
                title = prods[i].select('li > a.itemname')[0].text
                prod_url = prods[i].select('li > a.itemname')[0]['href']
                old_price = prods[i].select('li > div.item_price > div.o-price')[0].text.replace(',','')[:-1]
                dis_price = prods[i].select('li > div.item_price > div.s-price')[0].text.split('\n')[1].replace(',','')[:-1]
                dis_per = prods[i].select('li > div.item_price > div.s-price')[0].text.split('\n')[2][:-1]

                res = requests.get(prod_url)
                soup = BeautifulSoup(res.content, 'html.parser')

                try:
                    provider = soup.select(' div.item-topinfo_headline > p > span.text__brand > span.text')[0].text
                except:
                    provider = []
                try:
                    prod_code = soup.select('body > div.location-navi > div > span')[0].text.split(':')[1].strip()
                except:
                    prod_code = []

                print(ranking,title,old_price,dis_price,dis_per,provider, prod_code)
            except:
                pass

            category_name_list.append(cate_title)
            sub_category_name_list.append(sub_title)
            ranking_list.append(ranking)
            title_list.append(title)
            old_price_list.append(old_price)
            dis_price_list.append(dis_price)
            discount_percent_list.append(dis_per)
            item_code_list.append(prod_code)
            provider_list.append(provider)
            
#             print(ranking,title,old_price,dis_price,dis_per,provider, prod_code)
            
# data_dict['category_name'] = category_name_list
# data_dict['sub_category_name'] = sub_category_name_list
# data_dict['ranking'] = ranking_list
# data_dict['title'] = title_list
# data_dict['ori_price'] = old_price_list
# data_dict['dis_price'] = dis_price_list
# data_dict['discount_percent'] = discount_percent_list
# data_dict['item_code'] = item_code_list
# data_dict['provider'] = provider_list
# Out:
# ...
#
# ALL
# ...
#
# 패션의류
#
# 브랜드 여성의류
# 1 [올리비아로렌]올리비아로렌 봄준비하자 점퍼/코트/니트+25%쿠폰 87200 34900 59 올리비아로렌 1655774766
# 2 [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1 24900 24410 1 포커스 2344225657
# 3 [랩]LAP 22W/S 신상 추가 아우터/맨투맨/원피스 外 102000 51000 50 랩 2345098485
# 4 [크로커다일레이디]25%쿠폰 크로커다일레이디외 봄 신상겨울 베스트 모음 96000 48000 50 크로커다일레이디 2226812032
# 5 22%쿠폰 SOUP外 겨울 클리어런스 봄 BEST 상품 99800 49900 50 [] 1234579017
# 6 CERRUTI1881 세루티1881 22SPRING 세뛰르 원피스  119000  [] 2353020395
#
# 브랜드 남성의류
# 1 [폴햄][폴햄] 공용 경량점퍼 / 보아집업 5종택1 (PHB4JP1020 2020 2040 TC3 28000 21000 25 폴햄 2345692742
# 2 [레노마셔츠]레노마 인기 긴소매 셔츠 모음전 49000 30000 38 레노마셔츠앤타이 2218978341
# 3 [헤지스]20+10% 헤지스남성 니트/티셔츠 外 발렌타인 선물BEST 239000 119500 50 헤지스 2099438427
# 4 [니]NII 봄 프리뷰 맨투맨/후드/집업외+쿠폰혜택 35800 17900 50 NII 1652387921
# 5 [인디안]인디안 봄선오픈 정장SET  슈즈/넥타이/셔츠/팬츠외 58000 29000 50 인디안 1644625234
# 6 겨울쇼핑정복~ 데이리룩의 끝 TRUGEN 코트다운외 132900 39900 69 [] 2122240258
#
# 브랜드 진/캐쥬얼
# 1 [지오다노]20% 지오다노 신년SALE 맨투맨/조거/티셔츠 ~68% 45000 18000 60 지오다노 1766664761
# ...

# %%
data_dict['category_name'] = category_name_list
data_dict['sub_category_name'] = sub_category_name_list
data_dict['ranking'] = ranking_list
data_dict['title'] = title_list
data_dict['ori_price'] = old_price_list
data_dict['dis_price'] = dis_price_list
data_dict['discount_percent'] = discount_percent_list
data_dict['item_code'] = item_code_list
data_dict['provider'] = provider_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15068/3216499338.py in <module>
# ----> 1 data_dict['category_name'] = category_name_list
#       2 data_dict['sub_category_name'] = sub_category_name_list
#       3 data_dict['ranking'] = ranking_list
#       4 data_dict['title'] = title_list
#       5 data_dict['ori_price'] = old_price_list
#
# NameError: name 'category_name_list' is not defined

# %%
df = pd.DataFrame(data_dict)
df.head(2)
# Out:
#   category_name sub_category_name ranking  \
# 0          패션의류          브랜드 여성의류       1
# 1          패션의류          브랜드 여성의류       2
#
#                                     title ori_price dis_price  \
# 0     [올리비아로렌]올리비아로렌 봄준비하자 점퍼/코트/니트+25%쿠폰     87200     34900
# 1  [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1     24900     24410
#
#   discount_percent   item_code provider
# 0               59  1655774766   올리비아로렌
# 1                1  2344225657      포커스

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 648 entries, 0 to 647
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   category_name      648 non-null    object
#  1   sub_category_name  648 non-null    object
#  2   ranking            648 non-null    object
#  3   title              648 non-null    object
#  4   ori_price          648 non-null    object
#  5   dis_price          648 non-null    object
#  6   discount_percent   648 non-null    object
#  7   item_code          648 non-null    object
#  8   provider           648 non-null    object
# dtypes: object(9)
# memory usage: 45.7+ KB

# %%
import MySQLdb

# %%
db = MySQLdb.connect(host='localhost', port=3306, user='root', passwd='1234', charset='utf8')

# %%
cursor = db.cursor()

# %%
sql = """
show databases;
"""
pd.read_sql(sql, db)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15068/3147234508.py in <module>
#       2 show databases;
#       3 """
# ----> 4 pd.read_sql(sql, db)
#
# NameError: name 'pd' is not defined

# %%
sql = """
create database gmarketdb;
"""

cursor.execute(sql)
# Out:
# 1

# %%
sql = """
use gmarketdb;
"""
cursor.execute(sql)
# Out:
# 0

# %%
sql = """
create table ranking (
    main_category varchar(20),
    sub_category varchar(20),
    item_ranking int,
    item_code varchar(10),
    privider varchar(20))
"""

cursor.execute(sql)
# Out:
# 0

# %%
sql = """
create table item (
    item_code varchar(20) not null primary key,
    title varchar(200),
    old_price int,
    dis_price varchar(10),
    dis_percent int);"""

cursor.execute(sql)
# Out:
# 0

# %%
df.head(1)
# Out:
#   category_name sub_category_name ranking  \
# 0          패션의류          브랜드 여성의류       1
#
#                                  title ori_price dis_price discount_percent  \
# 0  [올리비아로렌]올리비아로렌 봄준비하자 점퍼/코트/니트+25%쿠폰     87200     34900               59
#
#     item_code provider
# 0  1655774766   올리비아로렌

# %%
for i in range(len(df)):
    
    item_code = item_code_list[i]
    prod_title = title_list[1]
    
    old_price = old_price_list[i]
    dis_price = dis_price_list[i]
    discount_percent = discount_percent_list[i]
    
    print(item_code, prod_title, old_price, dis_price, discount_percent)
    
    sql = "insert ignore into item values('{}', '{}','{}','{}','{}')"\
    .format(item_code, prod_title, old_price, dis_price, discount_percent)
    
    cursor.execute(sql)
# Out:
# 1655774766 [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1 87200 34900 59
# 2344225657 [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1 24900 24410 1
# 2345098485 [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1 102000 51000 50
# 2226812032 [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1 96000 48000 50
# 1234579017 [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1 99800 49900 50
# 2353020395 [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1  119000
# 2345692742 [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1 28000 21000 25
# 2218978341 [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1 49000 30000 38
# 2099438427 [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1 239000 119500 50
# 1652387921 [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1 35800 17900 50
# 1644625234 [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1 58000 29000 50
# 2122240258 [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1 132900 39900 69
# 1766664761 [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1 45000 18000 60
# 2344929845 [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1 49900 38930 21
# ...

# %%
sql = 'select * from item'

pd.read_sql(sql, db)
# Out:
#       item_code                                   title  old_price dis_price  \
# 0     106851199  [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1          0     97700
# 1    1107162855  [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1      15800      7900
# 2    1112606830  [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1      53900     53370
# 3    1112773981  [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1          0     24000
# 4    1124083462  [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1      27800     13900
# ..          ...                                     ...        ...       ...
# 593   974789162  [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1      20900     19110
# 594   986892178  [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1      27800     26970
# 595   990211575  [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1      31000     28520
# 596   992664246  [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1          0     25800
# 597          []  [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1     115000     92000
#
#      dis_percent
# 0              0
# ...

# %%
for i in range(len(df)):
    main_category = category_name_list[i]
    sub_category = sub_category_name_list[i]
    item_ranking = ranking_list[i]
    item_code = item_code_list[i]
    provider = provider_list[i]
    
#     print(main_category, sub_category, item_ranking, item_code, provider)
    
    sql = "insert ignore into ranking values('{}','{}','{}','{}','{}');".\
    format(main_category, sub_category, item_ranking, item_code, provider)
    
    print(sql)
    
    cursor.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15068/3335834939.py in <module>
# ----> 1 for i in range(len(df)):
#       2     main_category = category_name_list[i]
#       3     sub_category = sub_category_name_list[i]
#       4     item_ranking = ranking_list[i]
#       5     item_code = item_code_list[i]
#
# NameError: name 'df' is not defined

# %%
sql = 'select * from ranking;'

cursor.execute(sql)
# Out:
# 648

# %%
cursor.fetchall()
# Out:
# (('패션의류', '브랜드 여성의류', 1, '1655774766', '올리비아로렌'),
#  ('패션의류', '브랜드 여성의류', 2, '2344225657', '포커스'),
#  ('패션의류', '브랜드 여성의류', 3, '2345098485', '랩'),
#  ('패션의류', '브랜드 여성의류', 4, '2226812032', '크로커다일레이디'),
#  ('패션의류', '브랜드 여성의류', 5, '1234579017', '[]'),
#  ('패션의류', '브랜드 여성의류', 6, '2353020395', '[]'),
#  ('패션의류', '브랜드 남성의류', 1, '2345692742', '폴햄'),
#  ('패션의류', '브랜드 남성의류', 2, '2218978341', '레노마셔츠앤타이'),
#  ('패션의류', '브랜드 남성의류', 3, '2099438427', '헤지스'),
#  ('패션의류', '브랜드 남성의류', 4, '1652387921', 'NII'),
#  ('패션의류', '브랜드 남성의류', 5, '1644625234', '인디안'),
#  ('패션의류', '브랜드 남성의류', 6, '2122240258', '[]'),
#  ('패션의류', '브랜드 진/캐쥬얼 ', 1, '1766664761', '지오다노'),
#  ('패션의류', '브랜드 진/캐쥬얼 ', 2, '2344929845', '폴햄'),
#  ('패션의류', '브랜드 진/캐쥬얼 ', 3, '2337396354', '폴햄'),
#  ('패션의류', '브랜드 진/캐쥬얼 ', 4, '1350339365', '지오다노'),
#  ('패션의류', '브랜드 진/캐쥬얼 ', 5, '2072117982', '지프'),
#  ('패션의류', '브랜드 진/캐쥬얼 ', 6, '2333232364', '폴햄'),
#  ('패션의류', '여성의류', 1, '2266434001', '[]'),
#  ('패션의류', '여성의류', 2, '197555399', '[]'),
# ...

# %%
db.commit()  # 서버에 변경한 부분을 반영시키는 함수..

# %%
rank_df = pd.read_sql('select * from ranking;', db)

# %%
item_df = pd.read_sql('select * from item;', db)

# %%
# 할인율이 50% 이상인 제품의 카테고리를 출력하시오..

# %%
pd.read_sql('select * from item;', db).head(3)

# %%
merged_df = pd.merge(item_df, rank_df, on='item_code')
merged_df[merged_df['dis_percent'] >= 50][['dis_percent', 'main_category','sub_category']]
# Out:
#      dis_percent main_category   sub_category
# 1             50         신발/잡화        잡화/액세서리
# 4             50        유아동/출산            물티슈
# 18            59         가구/침구        커튼/블라인드
# 19            60       스포츠/자동차      스포츠의류/운동화
# 21            70        유아동/출산         유아동신발
# ..           ...           ...            ...
# 618           58         가구/침구     홈패션/인테리어소품
# 619           69       스포츠/자동차        휘트니스/수영
# 620           50        유아동/출산         임부복/용품
# 622           66        화장품/헤어  샴푸/헤어에센스/스타일링
# 624           70          패션의류           언더웨어
#
# [148 rows x 3 columns]

# %%
# '삼성전자' 제품의 평균 가격은

# %%
rank_df.head(2)
# Out:
#   main_category sub_category  item_ranking   item_code privider
# 0          패션의류     브랜드 여성의류             1  1655774766   올리비아로렌
# 1          패션의류     브랜드 여성의류             2  2344225657      포커스

# %%
item_df.head(2)
# Out:
#     item_code                                   title  old_price dis_price  \
# 0   106851199  [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1          0     97700
# 1  1107162855  [Focus]포커스 FW특가 가디건/원피스/스커트/팬츠 外 50종택1      15800      7900
#
#    dis_percent
# 0            0
# 1           50

# %%
merged_df = pd.merge(item_df, rank_df, on='item_code')
merged_df[merged_df.privider == '삼성전자'].dis_price.mean()
# Out:
# 4.828587578675e+75

# %%
merged_df.privider.value_counts()
# Out:
# []        243
# 삼성전자       14
# 애경          8
# 애플          7
# 매일유업        7
#          ...
# 제이에스티나      1
# 리르          1
# 퓨리나         1
# 베비언스        1
# 퍼실          1
# Name: privider, Length: 272, dtype: int64

# %%
# 카테고리별 제품의 평균가격?

# %%
merged_df.groupby('main_category').dis_price.mean()
# Out:
# main_category
# e쿠폰/티켓      3.256670e+157
# 가구/침구       9.966726e+145
# 도서/음반       1.650012e+301
# 생활/주방/건강              inf
# 스포츠/자동차     1.081253e+236
# 식품                    inf
# 신발/잡화       1.462989e+268
# 여행          5.416721e+118
# 유아동/출산                inf
# 컴퓨터/전자                inf
# 패션의류        1.386115e+172
# 화장품/헤어      8.104191e+229
# Name: dis_price, dtype: float64
