# %%
#  http://www/imdb.com

# 영화 평점 감독 제목 등 나타내기

# %%
url = 'https://www.imdb.com/movies-coming-soon/2022-02/'

# %%
Title : ...
Gene : ['']
content : 
    '''
    After being abducted by a child killer and locked in a soundproof basement, a 13-year-old boy starts receiving calls on a disconnected phone from the killer's previous victims.
    '''
Director : 
stars
-----------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.imdb.com/movies-coming-soon/2022-02/'

res = requests.get(url)

soup = BeautifulSoup(res.text, 'html.parser')

path = '#main > div > div.list.detail > div > table > tbody > tr'

movie = soup.select(path)

movie

# for i in movie:
#     print(i.select('td.overview-top > h4 > a')[0].text)
#     print(i.select('span')[0].text)
#     print(i.select('div.outlin')[0].text)
#     print(i.select('span > a')[0].text)
#     print(i.select('div > a')[0].text)
# Out:
# [<tr>
#  <td id="img_primary" rowspan="2" valign="top">
#  <div class="image">
#  <a href="/title/tt11466222/"> <div class="hover-over-image zero-z-index">
#  <img alt="Jackass Forever (2022) Poster" class="poster shadowed" height="209" src="https://m.media-amazon.com/images/M/MV5BNTdmMDNmYmItOWFmNC00YzdkLWIyZWMtMGRlMTQyZDZmNDU0XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_UY209_CR0,0,140,209_AL_.jpg" title="Jackass Forever (2022)" width="140"/>
#  </div>
#  </a> </div>
#  </td>
#  <td class="overview-top">
#  <h4><a href="/title/tt11466222/" title="Jackass Forever (2022)"> Jackass Forever (2022)</a></h4>
#  <p class="cert-runtime-genre">
#  <img alt="Certificate R" class="absmiddle certimage" src="https://m.media-amazon.com/images/S/sash/HnfGvvr0ifGfk6P.png" title="R"/>
#  <time datetime="PT96M">96 min</time>
#                                    -
#                                  <span>Documentary</span>
#  <span class="ghost">|</span>
#  <span>Action</span>
#  <span class="ghost">|</span>
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.imdb.com/movies-coming-soon/2022-02/'

res = requests.get(url)

soup = BeautifulSoup(res.text, 'html.parser')

path = '#main > div > div.list.detail > div > table > tbody > tr'

movie = soup.select(path)

movie
# Out:
# [<tr>
#  <td id="img_primary" rowspan="2" valign="top">
#  <div class="image">
#  <a href="/title/tt11466222/"> <div class="hover-over-image zero-z-index">
#  <img alt="Jackass Forever (2022) Poster" class="poster shadowed" height="209" src="https://m.media-amazon.com/images/M/MV5BNTdmMDNmYmItOWFmNC00YzdkLWIyZWMtMGRlMTQyZDZmNDU0XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_UY209_CR0,0,140,209_AL_.jpg" title="Jackass Forever (2022)" width="140"/>
#  </div>
#  </a> </div>
#  </td>
#  <td class="overview-top">
#  <h4><a href="/title/tt11466222/" title="Jackass Forever (2022)"> Jackass Forever (2022)</a></h4>
#  <p class="cert-runtime-genre">
#  <img alt="Certificate R" class="absmiddle certimage" src="https://m.media-amazon.com/images/S/sash/HnfGvvr0ifGfk6P.png" title="R"/>
#  <time datetime="PT96M">96 min</time>
#                                    -
#                                  <span>Documentary</span>
#  <span class="ghost">|</span>
#  <span>Action</span>
#  <span class="ghost">|</span>
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.imdb.com/movies-coming-soon/2022-02/'

# %%
res = requests.get(url)

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %%
path = '#main > div > div.list.detail > div > table > tbody > tr'

# %%
path = 'td.overview-top > h4 > a'

# %%
soup.select(path)[0].text
# Out:
# ' Jackass Forever (2022)'

# %%
path = '#main > div > div.list.detail > div > table > tbody > tr > td.overview-top > p span'

# %%
soup.select(path)
# Out:
# [<span>Documentary</span>,
#  <span class="ghost">|</span>,
#  <span>Action</span>,
#  <span class="ghost">|</span>,
#  <span>Comedy</span>,
#  <span class="certRating">15</span>,
#  <span>Horror</span>,
#  <span>Action</span>,
#  <span class="ghost">|</span>,
#  <span>Adventure</span>,
#  <span class="ghost">|</span>,
#  <span>Fantasy</span>,
#  <span class="ghost">|</span>,
#  <span>Sci-Fi</span>,
#  <span>Crime</span>,
#  <span class="ghost">|</span>,
#  <span>Drama</span>,
#  <span class="ghost">|</span>,
#  <span>Mystery</span>,
#  <span>Action</span>,
#  <span class="ghost">|</span>,
#  <span>Thriller</span>,
#  <span>Animation</span>,
#  <span class="ghost">|</span>,
#  <span>Action</span>,
#  <span class="ghost">|</span>,
#  <span>Sci-Fi</span>,
#  <span>Comedy</span>,
#  <span class="ghost">|</span>,
#  <span>Music</span>,
#  <span class="ghost">|</span>,
#  <span>Romance</span>,
#  <span>Drama</span>,
#  <span class="ghost">|</span>,
#  <span>Romance</span>,
# ...

# %%
g = []

for t in soup.selet(path)[0]: 
    if '|' not in t:
        g_list.append(t.text)
        
g_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9976/2008082848.py in <module>
#       1 g = []
#       2
# ----> 3 for t in soup.selet(path)[0]:
#       4     if '|' not in t:
#       5         g_list.append(t.text)
#
# TypeError: 'NoneType' object is not callable

# %%
#  딕셔너리로 만들기
