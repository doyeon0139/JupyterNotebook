# %%
# 구글 홈페이지에서 검색어를 입력한 후 이미지 검색 결과를 크롤링하기
# element에서 특정 속성값을 추출하는 메소드 : get_attribute('href'), get_attrivute('src')

# %%
import requests
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

import warnings
warnings.filterwarnings(action='ignore')

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.google.com/")

# %%
elem = driver.find_element_by_class_name("danawa-member-login-input-id")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6300/3370701925.py in <module>
# ----> 1 elem = driver.find_element_by_class_name("danawa-member-login-input-id")
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     758             stacklevel=2,
#     759         )
# --> 760         return self.find_element(by=By.CLASS_NAME, value=name)
#     761
#     762     def find_elements_by_class_name(self, name) -> WebElement:
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1242             value = '[name="%s"]' % value
#    1243
# -> 1244         return self.execute(Command.FIND_ELEMENT, {
#    1245             'using': by,
#    1246             'value': value})['value']
#
# ...

# %%
s = input('검색어')

elem.send_keys(s)

# %%
driver.find_element_by_css_selector("#hdtb-msb > div:nth-child(1) > div > div:nth-child(2) > a").click()

# %%
html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')

path = "#islrg"

bird = soup.select(path)

bird
# Out:
# [<div id="islrg"><div class="islrc" jsname="r5xl4" style="width: 1147px;"><div class="isv-r PNCib MSM1fd BUooTd" data-cb="3" data-cl="15" data-cr="9" data-ct="6" data-hveid="CAEQvQE" data-ictx="1" data-id="1EBtvTLugEgKWM" data-oh="549" data-os="-2" data-ow="976" data-ri="0" data-tbnid="1EBtvTLugEgKWM" data-tw="300" data-ved="2ahUKEwimz_3skML1AhU9zIsBHT9oA6gQMygAegUIARC9AQ" jsaction="dtRDof:s370ud;v03O1c:cJhY7b;" jscontroller="H9MIue" jsdata="j0Opre;1EBtvTLugEgKWM;14" jsmodel="lbVNPd Whqy4b" jsname="N9Xkfe" style="width: 270px; height: 222px;"><a class="wXeWr islib nfEiy" data-nav="1" jsaction="J9iaEb;mousedown:npT2md; touchstart:npT2md;" jsname="sTFXNd" style="height: 180px;" tabindex="0"><div class="bRMDJf islir" jsaction="mousedown:npT2md; touchstart:npT2md;" jsname="DeysSe" style="margin-top: 6px; height: 169px; margin-left: -18px; margin-right: -12px;"><img alt="Bird populations in US and Canada down 3bn in 50 years - BBC News" class="rg_i Q4LuWd" data-atf="true" data-deferred="1
# ...

# %%
for bb in bird:
    img = bb.select("#islrg > div.islrc > div:nth-child(1) > a.wXeWr.islib.nfEiy")

# %%
import requests
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

import warnings
warnings.filterwarnings(action='ignore')

# %%
url = "https://www.google.com/"

# %%
driver = webdriver.Chrome()
driver.get(url)

# %%
driver,find_elelment_by-cs_selectu('input.gLFyf.gafi')
elem : send_keys ("빅데이터")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6300/2590347947.py in <module>
# ----> 1 driver,find_elelment_by-cs_selectu('input.gLFyf.gafi')
#       2 elem : send_keys ("빅데이터")
#
# NameError: name 'find_elelment_by' is not defined

# %%
elem.send_Keys(keys)

# %%
driver.find_element_by_css_selector("")

# %%
import time

# %%
for i, img in enumerate(images):
    img.click()
    elem = driver.find_element_by_xpath("")
    imgUrl = elem.get_attribute('src')
    print(imgUrl)
    urllib.request.retrieve(imgUrl, '빅데이터'+ str(i) + '.jpg')

# %%
# 스크롤을 끝까지 내리는 코딩
SCROLL_PAUSE_TIME = 2

last_height = driver.execute_script("return document.body.scrollheight")

while True:
#     ㅇ걒ㄷㄱ.ㄷㅌㄷ쳣ㄷ_ㄴ갸ㅔㅅ('window.scrollTo(0, document.body.scrollHeight:')
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight:')
    time.sleep(SCROLL_PAUSE_TIME)
    
    new_height = driver.execute_script('window.scrollTo(0, document.body.scrollHeight:')
    
    new_hight = driver.execute_script('return document.body.scrollHeight')
    if new_height == last_height:
        try:
            time.sleep(SCROLL_PAUSE_TIME)
            driver.find_element_by_css_selector(".mye4qd").click()
        except:
            break
    last_heiht = new_height
# Out:
# ---------------------------------------------------------------------------
# JavascriptException                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6300/4268803404.py in <module>
#       6 while True:
#       7 #     ㅇ걒ㄷㄱ.ㄷㅌㄷ쳣ㄷ_ㄴ갸ㅔㅅ('window.scrollTo(0, document.body.scrollHeight:')
# ----> 8     driver.execute_script('window.scrollTo(0, document.body.scrollHeight:')
#       9     time.sleep(SCROLL_PAUSE_TIME)
#      10
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     876         command = Command.W3C_EXECUTE_SCRIPT
#     877
# --> 878         return self.execute(command, {
#     879             'script': script,
#     880             'args': converted_args})['value']
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
# ...
